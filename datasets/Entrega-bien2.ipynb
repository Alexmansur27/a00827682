# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
# %ls
# Out:
# 02_04_lectura-de-datos.ipynb        NYC_Free_Public_WiFi_03292017.csv
# 03_00_pivot_table.ipynb             README.md
# 07_02_pie_box_scatter_bubble.ipynb  requierementsEXL
# Canada.xlsx                         requirements.txt
# datasets/                           runtime.txt
# Medals.csv                          session_01/
# nhanes_2015_2016.csv                welcome_binder.ipynb

# %%
# %ls datasets/
# Out:
# adult.csv                  heart.csv
# airline_data.csv           marketing_campaign.csv
# antropometria00.csv        Medals.csv
# antropometria-dataset.csv  Medals.xlsx
# archive.zip                movies.csv
# Canada.xlsx                nhanes_2015_2016.csv
# Cartwheeldata.csv          NYC_Free_Public_WiFi_03292017.csv
# census.csv                 pokemon.csv
# cwurData.csv               sample_pivot.csv
# data.csv                   tips.csv
# headbrain.csv              weight-height.csv

# %%
import pandas as pd
import numpy as np

# %%
base="datasets/heart.csv"
df=pd.read_csv(base)
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# 5              N      0.0       Up             0
# 6              N      0.0       Up             0
# 7              N      0.0       Up             0
# 8              Y      1.5     Flat             1
# 9              N      0.0       Up             0

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.groupby(["Age","RestingBP"]).size()
# Out:
# Age  RestingBP
# 28   130          1
# 29   120          1
#      130          1
#      140          1
# 30   170          1
#                  ..
# 75   170          1
# 76   104          1
#      140          1
# 77   124          1
#      125          1
# Length: 526, dtype: int64

# %%
pd.pivot_table(df, 
               index="Age", 
               values="Cholesterol", 
               aggfunc='sum'
              )
# Out:
#      Cholesterol
# Age
# 28           132
# 29           710
# 30           237
# 31           489
# 32          1206
# 33           544
# 34          1143
# 35          2172
# 36          1142
# 37          2571
# 38          2344
# 39          3588
# 40          2982
# 41          5196
# 42          3820
# 43          4856
# 44          4742
# 45          4128
# 46          5212
# 47          3675
# 48          7074
# 49          4483
# 50          4980
# 51          6156
# 52          7210
# 53          5974
# 54         11831
# 55          8957
# 56          6642
# 57          7688
# 58          9126
# 59          6150
# 60          5365
# 61          5040
# 62          5836
# 63          4728
# 64          4517
# 65          4359
# 66          2333
# 67          3823
# 68          1585
# 69          2031
# 70          1202
# 71          1158
# 72           548
# 73             0
# 74          1290
# 75           738
# 76           310
# 77           475

# %%
pd.pivot_table(df, 
               index="Age", 
               values="Cholesterol", 
               columns="Sex"
              )
# Out:
# Sex           F           M
# Age
# 28          NaN  132.000000
# 29          NaN  236.666667
# 30   237.000000         NaN
# 31   219.000000  270.000000
# 32   198.000000  252.000000
# 33   246.000000  298.000000
# 34   185.500000  154.400000
# 35   170.000000  207.750000
# 36          NaN  190.333333
# 37   214.750000  244.571429
# 38    91.666667  159.153846
# 39   200.333333  248.916667
# 40   392.000000  215.833333
# 41   236.428571  208.294118
# 42   228.333333  209.000000
# 43   238.666667  180.533333
# 44   200.333333  258.812500
# 45   243.166667  222.416667
# 46   215.500000  217.500000
# 47   236.250000  182.000000
# 48   233.000000  226.227273
# 49   222.666667  209.800000
# 50   219.285714  191.388889
# 51   229.909091  151.125000
# 52   216.600000  197.645161
# 53   278.666667  159.333333
# 54   266.866667  217.444444
# 55   311.714286  199.264706
# 56   297.800000  156.151515
# 57   298.166667  184.343750
# 58   286.428571  203.457143
# 59   258.333333  167.968750
# 60   259.800000  150.592593
# 61   307.250000  141.148148
# 62   202.900000  152.280000
# 63   220.000000  142.000000
# 64   202.833333  206.250000
# 65   317.750000  181.647059
# 66   183.000000  177.888889
# 67   354.666667  229.916667
# 68   211.000000  152.666667
# 69   239.000000  149.333333
# 70          NaN  171.714286
# 71   238.666667  221.000000
# 72          NaN  137.000000
# 73     0.000000         NaN
# 74   269.000000  170.166667
# 75          NaN  246.000000
# 76   197.000000  113.000000
# 77          NaN  237.500000

# %%
pd.pivot_table(df, 
               index="Age", 
               values="Cholesterol", 
               columns="Sex",
               aggfunc="sum"
              )
# Out:
# Sex       F       M
# Age
# 28      NaN   132.0
# 29      NaN   710.0
# 30    237.0     NaN
# 31    219.0   270.0
# 32    198.0  1008.0
# 33    246.0   298.0
# 34    371.0   772.0
# 35    510.0  1662.0
# 36      NaN  1142.0
# 37    859.0  1712.0
# 38    275.0  2069.0
# 39    601.0  2987.0
# 40    392.0  2590.0
# 41   1655.0  3541.0
# 42    685.0  3135.0
# 43   2148.0  2708.0
# 44    601.0  4141.0
# 45   1459.0  2669.0
# 46    862.0  4350.0
# 47    945.0  2730.0
# 48   2097.0  4977.0
# 49   1336.0  3147.0
# 50   1535.0  3445.0
# 51   2529.0  3627.0
# 52   1083.0  6127.0
# 53   1672.0  4302.0
# 54   4003.0  7828.0
# 55   2182.0  6775.0
# 56   1489.0  5153.0
# 57   1789.0  5899.0
# 58   2005.0  7121.0
# 59    775.0  5375.0
# 60   1299.0  4066.0
# 61   1229.0  3811.0
# 62   2029.0  3807.0
# 63   1320.0  3408.0
# 64   1217.0  3300.0
# 65   1271.0  3088.0
# 66    732.0  1601.0
# 67   1064.0  2759.0
# 68    211.0  1374.0
# 69    239.0  1792.0
# 70      NaN  1202.0
# 71    716.0   442.0
# 72      NaN   548.0
# 73      0.0     NaN
# 74    269.0  1021.0
# 75      NaN   738.0
# 76    197.0   113.0
# 77      NaN   475.0

# %%
import matplotlib.pyplot as plt

# %%
a_x = plt.plot(2, 3, '.')

# %%
hist_plot = df["Age"].plot(kind="hist")

# %%
import seaborn as sns

path = "datasets/heart.csv"

df = pd.read_csv(path)

# Create Scatterplot
sns.lmplot(x="Age", 
           y="Cholesterol", 
           data=df
          )
plt.title("Age vs Cholesterol")
plt.show()
